# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/content/raw_house_data.csv")

# %%
data
# Out:
#            MLS  sold_price  zipcode   longitude   latitude  lot_acres  \
# 0     21530491   5300000.0    85637 -110.378200  31.356362    2154.00
# 1     21529082   4200000.0    85646 -111.045371  31.594213    1707.00
# 2      3054672   4200000.0    85646 -111.040707  31.594844    1707.00
# 3     21919321   4500000.0    85646 -111.035925  31.645878     636.67
# 4     21306357   3411450.0    85750 -110.813768  32.285162       3.21
# ...        ...         ...      ...         ...        ...        ...
# 4995  21810382    495000.0    85641 -110.661829  31.907917       4.98
# 4996  21908591    550000.0    85750 -110.858556  32.316373       1.42
# 4997  21832452    475000.0    85192 -110.755428  32.964708      12.06
# 4998  21900515    550000.0    85745 -111.055528  32.296871       1.01
# 4999   4111490    450000.0    85621 -110.913054  31.385259       4.16
#
#          taxes  year_built  bedrooms bathrooms sqrt_ft garage  \
# 0      5272.00        1941        13        10   10500      0
# ...

# %%
data=data.to_numpy()
data
# Out:
# array([[21530491, 5300000.0, 85637, ..., '6', 'Mexican Tile, Wood', '0'],
#        [21529082, 4200000.0, 85646, ..., '5', 'Natural Stone, Other',
#         '0'],
#        [3054672, 4200000.0, 85646, ..., '5',
#         'Natural Stone, Other: Rock', 'None'],
#        ...,
#        [21832452, 475000.0, 85192, ..., '0', 'Ceramic Tile', 'None'],
#        [21900515, 550000.0, 85745, ..., '1', 'Carpet, Ceramic Tile',
#         'None'],
#        [4111490, 450000.0, 85621, ..., '3', 'Carpet, Mexican Tile',
#         'None']], dtype=object)

# %%
for i in range(0,4995):
  if data[:,7][i]==0:
    data=np.delete(data,i,0)

# %%
plt.figure(figsize=(12,8))
plt.scatter(data[:,7],data[:,15])
plt.yticks(ticks=[100,200,300,400], labels=['$100','$200','$300','$400'])
plt.title("HOA vs Year Built", fontsize=20)
# Out:
# Text(0.5, 1.0, 'HOA vs Year Built')

# %%
data[np.where(data == "None")] = 0
data[:,15]
# Out:
# array(['0', '0', 0, ..., 0, 0, 0], dtype=object)

# %%
k=0
for i in data[:,9]:
  data[:,9][k]=np.floor(float(i))
  k+=1

# %%
plt.figure(figsize=(12,8))
plt.scatter(data[:,7],data[:,6])
plt.title("Tax Amount vs Year Built", fontsize=20)
plt = plt.gca()
plt.set_ylim([0, 30000])
# Out:
# (0.0, 30000.0)
